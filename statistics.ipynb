# %%
import numpy as np
import copy
import pandas as pd
import matplotlib.pyplot as plt
import math
from scipy.stats import t
import seaborn as sn
from sklearn.linear_model import LinearRegression
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 50em; }</style>"))
std=0
p = 0.95
# 10%  или менее, но не 0=>10
# 90  или более, но не 100%=>90
# Облаков нет.=>0
# 20–30%.=>25
# 40%.=>40
# 50%.=>50
# 60%.=>60
# 70 – 80%.=>75
# 100%.=>100
def korrel(df):
    global p
    df_T = df['T'].dropna().values
    df_P = df['Po'].dropna().values
    otklonenie_T = []
    otklonenie_P = []
    multiply = []
    for j in range (0, len(df_P)):
        otklonenie_P.append(math.pow(df_P[j]-df['Po'].dropna().mean(),2))
        otklonenie_T.append(math.pow(df_T[j]-df['T'].dropna().mean(),2))
        multiply.append((df_T[j]-df_T.mean())*(df_P[j]-df_P.mean()))
    rxy=sum(multiply)/math.sqrt(sum(otklonenie_P)*sum(otklonenie_T))
    print('значение коэффициента корреляции Пирсона ',rxy)
    t_nab=rxy*math.sqrt(len(df['Po'].dropna()) - 2)/(math.sqrt(1-rxy*rxy))
    st = len(df['Po'].dropna()) - 2
    t_krit=t.ppf(p, st)
    print('t критерий наблюдаемый',t_nab)
    print('t критерий по таблице ',t_krit)
    if t_nab>t_krit:
        print('критерий наблюдаемый больше табличного, полученное значение коэффициента корреляции признается значимым')
    else:
        print('критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым')

    xs = df['T'].dropna()
    ys = df['Po'].dropna()
    pd.DataFrame(np.array([xs, ys]).T).plot.scatter(0, 1, s=12, grid=True)
    plt.xlabel('Темпераура')
    plt.ylabel('Давление')
    plt.show()

# тут
def cloud(df):
    for i in range(0, 12):
        cloud = []
        for j in range(0, len(df[i]['T'])):
            t1 = df[i].reset_index(drop=True)
            t = t1['N'].iloc[j]
            if t == '10%  или менее, но не 0':
                cloud.append(10)
            elif t == '90  или более, но не 100%':
                cloud.append(90)
            elif t == 'Облаков нет.':
                cloud.append(0)
            elif t == '20–30%.':
                cloud.append(25)
            elif t == '40%.':
                cloud.append(40)
            elif t == '50%.':
                cloud.append(50)
            elif t == '60%.':
                cloud.append(60)
            elif t == '70 – 80%.':
                cloud.append(75)
            elif t == '100%.':
                cloud.append(100)
            elif t == '0%.':
                cloud.append(0)
            else:
                # неба не видно туман
                cloud.append(t)
        df[i].insert(loc=5, column='cloud', value=cloud)
    return df

# тут
def wind(df):
    for i in range(0, 12):
        wind = []
        for j in range(0, len(df[i]['T'])):
            t1 = df[i].reset_index(drop=True)
            t = t1['DD'].iloc[j]
            if t == 'Ветер, дующий с севера':
                wind.append(360)
            elif t == 'Ветер, дующий с северо-северо-востока':
                wind.append(22.5)
            elif t == 'Ветер, дующий с северо-востока':
                wind.append(45)
            elif t == 'Ветер, дующий с востоко-северо-востока':
                wind.append(67.5)
            elif t == 'Ветер, дующий с востока':
                wind.append(90)
            elif t == 'Ветер, дующий с востоко-юго-востока':
                wind.append(112.5)
            elif t == 'Ветер, дующий с юго-востока':
                wind.append(135)
            elif t == 'Ветер, дующий с юго-юго-востока':
                wind.append(157.5)
            elif t == 'Ветер, дующий с юга':
                wind.append(180)
            elif t == 'Ветер, дующий с юго-юго-запада':
                wind.append(202.5)
            elif t == 'Ветер, дующий с юго-запада':
                wind.append(225)
            elif t == 'Ветер, дующий с западо-юго-запада':
                wind.append(247.5)
            elif t == 'Ветер, дующий с запада':
                wind.append(270)
            elif t == 'Ветер, дующий с западо-северо-запада':
                wind.append(292.5)
            elif t == 'Ветер, дующий с северо-запада':
                wind.append(315)
            elif t == 'Ветер, дующий с северо-северо-запада':
                wind.append(337.5)
            elif t == 'Штиль, безветрие':
                wind.append(0)
            else:
                wind.append(t)
        df[i].insert(loc=5, column='wind', value=wind)
        # print(df[i].columns)
    return df
#
def read_update():
    cf = pd.read_csv('7.csv', encoding='utf-8', sep=';', skiprows=6, comment='g', index_col=False)
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_colwidth', None)
    pd.set_option('display.width', None)
    # print(cf)
    t = cf['Местное время в По'].str.split(' ', expand=True)
    date = t[0].str.split('.', expand=True)
    time = t[1]
    cf.insert(loc=0, column='date', value=date[0])
    cf.insert(loc=1, column='mounth', value=date[1])
    cf.insert(loc=2, column='year', value=date[2])
    cf.insert(loc=3, column='time', value=time)
    df = []
    df.append(cf[cf['mounth'] == '01'])
    df.append(cf[cf['mounth'] == '02'])
    df.append(cf[cf['mounth'] == '03'])
    df.append(cf[cf['mounth'] == '04'])
    df.append(cf[cf['mounth'] == '05'])
    df.append(cf[cf['mounth'] == '06'])
    df.append(cf[cf['mounth'] == '07'])
    df.append(cf[cf['mounth'] == '08'])
    df.append(cf[cf['mounth'] == '09'])
    df.append(cf[cf['mounth'] == '10'])
    df.append(cf[cf['mounth'] == '11'])
    df.append(cf[cf['mounth'] == '12'])
    return df
#
def confidence_interval (df):
    global p,std
    st = len(df) - 1
    print('критичекое значение при  уровне значимости ', p * 100, '% и ', st, ' степени(ях) свободы', t.ppf(p, st))
    L=df.mean()-t.ppf(p, st)*std/math.sqrt(len(df))
    R=df.mean()+t.ppf(p, st)*std/math.sqrt(len(df))
    print('доверительный интервал для среднего',L,'  ',R)

def print_stat(df):
    global std
    print(df.max())
    print(df.min())
    print('размах', df.max() - df.min())
    print('среднее', df.mean())
    print('медианное', df.median())
    std=df.std()*pow(len(df),0.5)/pow(len(df)-1,0.5)
    print('отклонение',std)
    confidence_interval(df)
    print('коэффициент вариации ', std / df.mean() * 100, '%')
    
def day_night(df):
    df_mounth_day = []
    df_mounth_night = []
    for i in range(0, 12):
        df_night = df[i].query('time in ["21:00","00:00","03:00","06:00"]')
        df_day = df[i].query('time in ["09:00","12:00","15:00","18:00"]')
        df_mounth_day.append(df_day)
        df_mounth_night.append(df_night)
    return [df_mounth_day, df_mounth_night]

def gistogramms (df_day,df_night,name,column_name):
    plt.hist(df_day[column_name].dropna(),bins=150, alpha=0.5, label='day')
    plt.hist(df_night[column_name].dropna(),bins=150,  alpha=0.5, label='night')
    plt.legend(loc='upper right')
    plt.xlabel(name)
    plt.ylabel('Частота')
    plt.show()

def stat(df_day, df_night):
    for i in range(0, 12):
        print()
        print('//////////////////////////////////////////////////////////////////////////////////')
        print('номер месяца ', i+1)
        print('\nТемпература день')
        print_stat(df_day[i]['T'].dropna())
        print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ')
        print('Температура ночь')
        print_stat(df_night[i]['T'].dropna())
        gistogramms(df_day[i],df_night[i],'Температура','T')
        print('\nВлажность день')
        print_stat(df_day[i]['U'].dropna())
        print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ')
        print('Влажность ночь')
        print_stat(df_night[i]['U'].dropna())
        gistogramms(df_day[i], df_night[i], 'Влажность', 'U')
        print('\nДавление день')
        print_stat(df_day[i]['Po'].dropna())
        print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ')
        print('Давление ночь')
        print_stat(df_night[i]['Po'].dropna())
        gistogramms(df_day[i], df_night[i], 'Давление', 'Po')
        print('\nОблачность день')
        print_stat(df_day[i]['cloud'].dropna())
        print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ')
        print('Облачность ночь')
        print_stat(df_night[i]['cloud'].dropna())
        gistogramms(df_day[i], df_night[i], 'Облачность', 'cloud')
        print('\nВетер день')
        print_stat(df_day[i]['wind'].dropna())
        print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ')
        print('Ветер ночь')
        print_stat(df_night[i]['wind'].dropna())
        gistogramms(df_day[i], df_night[i], 'Ветер', 'wind')
        print('корреляция T/Po')
        print('день')
        korrel(df_day[i])
        print('ночь')
        korrel(df_night[i])
        correl_matrix(df_day[i], i, 'дневное время')
        correl_matrix(df_night[i], i, 'ночное время')

def regres(matr,dataset):
    col = ['T', 'Po', 'U', 'cloud', 'wind']
    for i in range(0,len(col)):
        x_y_cp=0
        t1 = matr[col[i]].reset_index(drop=True)
        for j in range(i, len(matr[col[i]])):
            t = float(t1.iloc[j])
            if (t>=0.7 and t<1)  or (t<=-0.7 and t >-1):
                X = dataset[[col[i]]]
                y = dataset[[col[j]]]
                for u in range(0, len(X)):
                    t = X.iloc[u].values[0]*y.iloc[u].values[0]
                    x_y_cp=t+x_y_cp
                regressor = LinearRegression()
                regressor.fit(X, y)
                plt.scatter(X, y, color='red')
                plt.plot(X, regressor.predict(X), color='blue')
                plt.title(col[i]+' and '+col[j])
                plt.xlabel(col[i])
                plt.ylabel(col[j])
                plt.show()
                m_X = dataset[[col[i]]].mean().values[0]
                m_y = dataset[[col[j]]].mean().values[0]
                r_v=(x_y_cp/len(X)-m_X*m_y)/(dataset[[col[i]]].std().values[0]*dataset[[col[j]]].std().values[0])
                print('x='+col[i]+'  y='+col[j])
                a=r_v*(dataset[[col[j]]].std().values[0])/(dataset[[col[i]]].std().values[0])
                b=(-1)*r_v*(dataset[[col[j]]].std().values[0])/(dataset[[col[i]]].std().values[0])*m_X+m_y
                if b>0:
                    print("уравнение линейной регрессии")
                    print("y="+str(a)+'x+'+str(b))
                else:
                    print("уравнение линейной регрессии")
                    print("y=" + str(a) + 'x' + str(b))


def correl_matrix(df, i, name):
    df = copy.deepcopy(df[['T', 'Po', 'U', 'cloud', 'wind']].dropna())
    numeric_col = ['T', 'Po', 'U', 'cloud', 'wind']
    corr_matrix = df.loc[:, numeric_col].corr().fillna(0)
    corr_matrix.loc['T', 'T'] = 1
    corr_matrix.loc['Po', 'Po'] = 1
    corr_matrix.loc['U', 'U'] = 1
    corr_matrix.loc['cloud', 'cloud'] = 1
    corr_matrix.loc['wind', 'wind'] = 1
    stroka = 'Корреляционная матрица за ' + name + ' ' + str(i + 1) + ' меяца'
    sn.heatmap(corr_matrix, vmin=-1, vmax=1, annot=True, cmap='BrBG').set_title(stroka, fontdict={'fontsize': 10},pad=16)
    plt.show()
    regres(copy.deepcopy(corr_matrix),copy.deepcopy(df))

df_mounth = read_update()
df_mounth_day_night = day_night(df_mounth)
df_mounth_day = df_mounth_day_night[0]
df_mounth_night = df_mounth_day_night[1]
wind_day = wind(df_mounth_day)
wind_night = wind(df_mounth_night)
cloud_night = cloud(df_mounth_night)
cloud_day = cloud(df_mounth_day)
stat(cloud_day,cloud_night)
# Out:
# <style>div.output_scroll { height: 50em; }</style>
# //////////////////////////////////////////////////////////////////////////////////
# номер месяца  1
#
# Температура день
# 36.6
# 18.6
# размах 18.0
# среднее 29.575609756097563
# медианное 30.4
# отклонение 4.1268605781705485
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 28.958865766586833    30.192353745608294
# коэффициент вариации  13.953594235938683 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Температура ночь
# 27.3
# 13.7
# размах 13.600000000000001
# среднее 21.18114754098361
# медианное 21.45
# отклонение 3.0668245599697697
# критичекое значение при  уровне значимости  95.0 % и  121  степени(ях) свободы 1.6575443190799364
# доверительный интервал для среднего 20.720918344393056    21.641376737574163
# коэффициент вариации  14.479029306772642 %
# Влажность день
# 44.0
# 6.0
# размах 38.0
# среднее 20.0
# медианное 19.0
# отклонение 7.785081758364058
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 18.836548438850063    21.163451561149937
# коэффициент вариации  38.92540879182029 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Влажность ночь
# 62.0
# 17.0
# размах 45.0
# среднее 34.48760330578512
# медианное 34.0
# отклонение 8.882793917331291
# критичекое значение при  уровне значимости  95.0 % и  120  степени(ях) свободы 1.6576508993473795
# доверительный интервал для среднего 33.149005912532246    35.826200699038
# коэффициент вариации  25.756483680735354 %
# Давление день
# 735.9
# 728.6
# размах 7.2999999999999545
# среднее 731.8959349593496
# медианное 731.6
# отклонение 1.5220395551421633
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 731.6684717994849    732.1233981192142
# коэффициент вариации  0.20795846546499802 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Давление ночь
# 735.3
# 730.7
# размах 4.599999999999909
# среднее 732.3286885245902
# медианное 732.2
# отклонение 0.8902391722216856
# критичекое значение при  уровне значимости  95.0 % и  121  степени(ях) свободы 1.6575443190799364
# доверительный интервал для среднего 732.1950929924711    732.4622840567093
# коэффициент вариации  0.12156278815394148 %
# Облачность день
# 90
# 40
# размах 50
# среднее 83.04878048780488
# медианное 90.0
# отклонение 13.152098470139068
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 81.08324820793624    85.01431276767352
# коэффициент вариации  15.836594339961874 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Облачность ночь
# 90
# 50
# размах 40
# среднее 82.25409836065573
# медианное 90.0
# отклонение 13.11923275771425
# критичекое значение при  уровне значимости  95.0 % и  121  степени(ях) свободы 1.6575443190799364
# доверительный интервал для среднего 80.28533430718578    84.22286241412569
# коэффициент вариации  15.949640223628686 %
# Ветер день
# 360.0
# 22.5
# размах 337.5
# среднее 84.51219512195122
# медианное 67.5
# отклонение 80.02355895551307
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 72.55297138026884    96.4714188636336
# коэффициент вариации  94.68877105847145 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Ветер ночь
# 360.0
# 22.5
# размах 337.5
# среднее 202.6844262295082
# медианное 348.75
# отклонение 163.60350205347353
# критичекое значение при  уровне значимости  95.0 % и  121  степени(ях) свободы 1.6575443190799364
# доверительный интервал для среднего 178.13293760108357    227.23591485793284
# коэффициент вариации  80.71833889606216 %
# корреляция T/Po
# день
# значение коэффициента корреляции Пирсона  -0.7009538361722767
# t критерий наблюдаемый -10.811021242917883
# t критерий по таблице  1.6575443190799364
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# ночь
# значение коэффициента корреляции Пирсона  -0.1380570561276149
# t критерий наблюдаемый -1.5269610325534302
# t критерий по таблице  1.6576508993473795
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# x=T  y=Po
# уравнение линейной регрессии
# y=-0.25641904497387125x+739.479684567528
# //////////////////////////////////////////////////////////////////////////////////
# номер месяца  2
#
# Температура день
# 38.8
# 25.0
# размах 13.799999999999997
# среднее 32.611999999999995
# медианное 32.849999999999994
# отклонение 3.5757370312712324
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 32.01828778571084    33.20571221428915
# коэффициент вариации  10.96448249500562 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Температура ночь
# 31.0
# 15.8
# размах 15.2
# среднее 22.756000000000004
# медианное 23.0
# отклонение 3.469026297788692
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 22.18000594152328    23.331994058476727
# коэффициент вариации  15.244446729604022 %
# Влажность день
# 28.0
# 9.0
# размах 19.0
# среднее 16.56
# медианное 16.0
# отклонение 4.113778203183697
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 15.876951905370305    17.243048094629692
# коэффициент вариации  24.84165581632668 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Влажность ночь
# 49.0
# 21.0
# размах 28.0
# среднее 33.33
# медианное 33.0
# отклонение 5.231221365201208
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 32.46141263101605    34.198587368983944
# коэффициент вариации  15.69523361896552 %
# Давление день
# 735.1
# 727.9
# размах 7.2000000000000455
# среднее 731.3589999999999
# медианное 731.3
# отклонение 1.7593219585108917
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 731.0668837379537    731.6511162620461
# коэффициент вариации  0.24055517994731615 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Давление ночь
# 733.9
# 729.2
# размах 4.699999999999932
# среднее 731.7280000000001
# медианное 731.75
# отклонение 1.2133058184483863
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 731.526543774953    731.9294562250471
# коэффициент вариации  0.1658137748519103 %
# Облачность день
# 90
# 40
# размах 50
# среднее 75.2
# медианное 90.0
# отклонение 18.472977366035078
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 72.13276317565139    78.26723682434861
# коэффициент вариации  24.565129476110474 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Облачность ночь
# 90
# 40
# размах 50
# среднее 77.6
# медианное 90.0
# отклонение 16.29490491319255
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 74.89440839943329    80.3055916005667
# коэффициент вариации  20.998588805660503 %
# Ветер день
# 360.0
# 22.5
# размах 337.5
# среднее 84.375
# медианное 67.5
# отклонение 73.9509972887452
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 72.09624181246545    96.65375818753455
# коэффициент вариации  87.64562641629061 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Ветер ночь
# 360.0
# 22.5
# размах 337.5
# среднее 226.575
# медианное 360.0
# отклонение 159.87646961698297
# критичекое значение при  уровне значимости  95.0 % и  99  степени(ях) свободы 1.6603911559963895
# доверительный интервал для среднего 200.02925237960358    253.1207476203964
# коэффициент вариации  70.56227280899613 %
# корреляция T/Po
# день
# значение коэффициента корреляции Пирсона  -0.779898508856805
# t критерий наблюдаемый -12.335081287454306
# t критерий по таблице  1.6605512170440568
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# ночь
# значение коэффициента корреляции Пирсона  -0.1928056926558227
# t критерий наблюдаемый -1.9451764076710913
# t критерий по таблице  1.6605512170440568
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# x=T  y=Po
# уравнение линейной регрессии
# y=-0.37988577863601614x+743.7478350128777
# //////////////////////////////////////////////////////////////////////////////////
# номер месяца  3
#
# Температура день
# 42.2
# 26.9
# размах 15.300000000000004
# среднее 36.65645161290323
# медианное 37.8
# отклонение 3.313306884629377
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 36.163321539805644    37.14958168600082
# коэффициент вариации  9.038809646984703 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Температура ночь
# 35.1
# 22.0
# размах 13.100000000000001
# среднее 28.913709677419355
# медианное 29.1
# отклонение 2.6796574068028356
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 28.514887685100042    29.312531669738668
# коэффициент вариации  9.267774480337813 %
# Влажность день
# 71.0
# 6.0
# размах 65.0
# среднее 27.29032258064516
# медианное 24.5
# отклонение 14.10962434325145
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 25.190342009559167    29.390303151731153
# коэффициент вариации  51.7019331726708 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Влажность ночь
# 83.0
# 16.0
# размах 67.0
# среднее 40.306451612903224
# медианное 37.0
# отклонение 15.527978539482808
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 37.99537284511515    42.6175303806913
# коэффициент вариации  38.524796696596006 %
# Давление день
# 733.2
# 726.1
# размах 7.100000000000023
# среднее 729.1903225806451
# медианное 729.3499999999999
# отклонение 1.709627550073676
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 728.9358732380115    729.4447719232787
# коэффициент вариации  0.23445560056573556 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Давление ночь
# 731.9
# 727.5
# размах 4.399999999999977
# среднее 729.4911290322578
# медианное 729.4
# отклонение 0.8962296447776082
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 729.3577403044308    729.6245177600849
# коэффициент вариации  0.12285682568430208 %
# Облачность день
# 90
# 50
# размах 40
# среднее 89.55645161290323
# медианное 90.0
# отклонение 3.8416247223843127
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 88.98469030429906    90.1282129215074
# коэффициент вариации  4.289612477043266 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Облачность ночь
# 90
# 90
# размах 0
# среднее 90.0
# медианное 90.0
# отклонение 0.0
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 90.0    90.0
# коэффициент вариации  0.0 %
# Ветер день
# 360.0
# 0.0
# размах 360.0
# среднее 141.71370967741936
# медианное 90.0
# отклонение 98.15571389448921
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 127.10488047651357    156.32253887832513
# коэффициент вариации  69.26338610281213 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Ветер ночь
# 360.0
# 0.0
# размах 360.0
# среднее 221.00806451612902
# медианное 202.5
# отклонение 115.51883581356589
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 203.81502628198288    238.20110275027517
# коэффициент вариации  52.26905908002981 %
# корреляция T/Po
# день
# значение коэффициента корреляции Пирсона  -0.7041819396031476
# t критерий наблюдаемый -10.954548333404665
# t критерий по таблице  1.6574394994001826
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# ночь
# значение коэффициента корреляции Пирсона  -0.2669331342691897
# t критерий наблюдаемый -3.0593823648743244
# t критерий по таблице  1.6574394994001826
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# x=T  y=Po
# уравнение линейной регрессии
# y=-0.36041939512167187x+742.4020186982746
# //////////////////////////////////////////////////////////////////////////////////
# номер месяца  4
#
# Температура день
# 42.9
# 24.7
# размах 18.2
# среднее 35.55546218487395
# медианное 36.1
# отклонение 3.8353844397442094
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 34.972573306574034    36.13835106317387
# коэффициент вариации  10.787047064110062 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Температура ночь
# 36.2
# 23.4
# размах 12.800000000000004
# среднее 30.089166666666664
# медианное 30.15
# отклонение 2.917981891293262
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 29.647582555579827    30.5307507777535
# коэффициент вариации  9.697782340133255 %
# Влажность день
# 79.0
# 8.0
# размах 71.0
# среднее 42.596638655462186
# медианное 42.0
# отклонение 14.655250163971008
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 40.36938283183178    44.823894479092594
# коэффициент вариации  34.40471038691162 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Влажность ночь
# 96.0
# 24.0
# размах 72.0
# среднее 61.083333333333336
# медианное 64.0
# отклонение 14.41263441528946
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 58.90224016901818    63.26442649764849
# коэффициент вариации  23.595035877690794 %
# Давление день
# 732.9
# 726.2
# размах 6.699999999999932
# среднее 729.4100840336134
# медианное 729.5
# отклонение 1.661388318913534
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 729.1575918026921    729.6625762645348
# коэффициент вариации  0.22777150402502142 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Давление ночь
# 733.3
# 727.5
# размах 5.7999999999999545
# среднее 729.7883333333334
# медианное 729.7
# отклонение 1.0961939276601875
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 729.6224440855046    729.9542225811622
# коэффициент вариации  0.15020710493593176 %
# Облачность день
# 90
# 60
# размах 30
# среднее 88.8655462184874
# медианное 90.0
# отклонение 4.867166877731351
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 88.12585050181798    89.60524193515681
# коэффициент вариации  5.477001025532205 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Облачность ночь
# 90
# 60
# размах 30
# среднее 88.75
# медианное 90.0
# отклонение 5.377494707823919
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 87.9362128317129    89.5637871682871
# коэффициент вариации  6.059148966562162 %
# Ветер день
# 360.0
# 22.5
# размах 337.5
# среднее 195.12605042016807
# медианное 202.5
# отклонение 74.2499118591313
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 183.84179755911114    206.410303281225
# коэффициент вариации  38.052280410149116 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Ветер ночь
# 360.0
# 22.5
# размах 337.5
# среднее 200.625
# медианное 180.0
# отклонение 52.117695159305654
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 192.73792360741257    208.51207639258743
# коэффициент вариации  25.977667369124312 %
# корреляция T/Po
# день
# значение коэффициента корреляции Пирсона  -0.6792205018897217
# t критерий наблюдаемый -10.01028751564676
# t критерий по таблице  1.6579816587044385
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# ночь
# значение коэффициента корреляции Пирсона  -0.28589056615890873
# t критерий наблюдаемый -3.240831400379628
# t критерий по таблице  1.6578695221021444
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# x=T  y=U
# уравнение линейной регрессии
# y=-3.4567554196646535x+165.50317526170687
# x=T  y=U
# уравнение линейной регрессии
# y=-4.119945321677183x+185.0490547748317
#
# //////////////////////////////////////////////////////////////////////////////////
# номер месяца  5
#
# Температура день
# 40.4
# 23.4
# размах 17.0
# среднее 33.58943089430894
# медианное 34.0
# отклонение 3.6117922142883256
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 33.0496619592238    34.12919982939408
# коэффициент вариации  10.752763944268768 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Температура ночь
# 34.4
# 22.6
# размах 11.799999999999997
# среднее 28.410483870967738
# медианное 28.4
# отклонение 2.583685474262696
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 28.02594568867773    28.795022053257746
# коэффициент вариации  9.094126963824529 %
# Влажность день
# 96.0
# 29.0
# размах 67.0
# среднее 52.08130081300813
# медианное 49.0
# отклонение 13.210241521390904
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 50.10707927002722    54.055522355989034
# коэффициент вариации  25.36465356120951 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Влажность ночь
# 94.0
# 47.0
# размах 47.0
# среднее 71.40322580645162
# медианное 71.0
# отклонение 10.714978338313832
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 69.80848127019267    72.99797034271056
# коэффициент вариации  15.006294487812461 %
# Давление день
# 734.0
# 727.4
# размах 6.600000000000023
# среднее 730.5601626016261
# медианное 730.4
# отклонение 1.5598130215470012
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 730.327054337468    730.7932708657842
# коэффициент вариации  0.21350918122777057 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Давление ночь
# 733.2
# 728.6
# размах 4.600000000000023
# среднее 730.8983870967743
# медианное 730.9
# отклонение 1.0161456846091474
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 730.7471508807589    731.0496233127897
# коэффициент вариации  0.13902694308102298 %
# Облачность день
# 90
# 75
# размах 15
# среднее 89.63414634146342
# медианное 90.0
# отклонение 2.3328277820914276
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 89.28551389170755    89.98277879121929
# коэффициент вариации  2.602610586823089 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Облачность ночь
# 100
# 90
# размах 10
# среднее 90.16129032258064
# медианное 90.0
# отклонение 1.26995929689539
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 89.97227821391837    90.35030243124291
# коэффициент вариации  1.4085416173079461 %
# Ветер день
# 360.0
# 22.5
# размах 337.5
# среднее 198.84146341463415
# медианное 202.5
# отклонение 54.83572097958329
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 190.6464685307416    207.0364582985267
# коэффициент вариации  27.57760883364508 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Ветер ночь
# 360.0
# 22.5
# размах 337.5
# среднее 193.97177419354838
# медианное 202.5
# отклонение 44.40376871154317
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 187.36301911199752    200.58052927509925
# коэффициент вариации  22.891871199381992 %
# корреляция T/Po
# день
# значение коэффициента корреляции Пирсона  -0.6870235226213959
# t критерий наблюдаемый -10.400348064388186
# t критерий по таблице  1.6575443190799364
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# ночь
# значение коэффициента корреляции Пирсона  -0.4097710795841765
# t критерий наблюдаемый -4.961770560278583
# t критерий по таблице  1.6574394994001826
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# x=T  y=U
# уравнение линейной регрессии
# y=-3.392277999476099x+166.02598825069515
# x=T  y=U
# уравнение линейной регрессии
# y=-3.6661855667475525x+175.5613317185077
#
# //////////////////////////////////////////////////////////////////////////////////
# номер месяца  6
#
# Температура день
# 38.4
# 20.6
# размах 17.799999999999997
# среднее 30.01008403361345
# медианное 30.2
# отклонение 3.6848428253475185
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 29.450073965542785    30.570094101684113
# коэффициент вариации  12.278682129714232 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Температура ночь
# 32.4
# 21.1
# размах 11.299999999999997
# среднее 26.088333333333335
# медианное 25.95
# отклонение 2.3755760026860466
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 25.728832604217978    26.447834062448692
# коэффициент вариации  9.105894088108528 %
# Влажность день
# 96.0
# 36.0
# размах 60.0
# среднее 65.08403361344538
# медианное 64.0
# отклонение 13.723016143581166
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 62.998455593173404    67.16961163371737
# коэффициент вариации  21.085073222545624 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Влажность ночь
# 98.0
# 54.0
# размах 44.0
# среднее 82.79166666666667
# медианное 85.0
# отклонение 9.739401541006037
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 81.31778330061988    84.26555003271346
# коэффициент вариации  11.76374619950402 %
# Давление день
# 735.9
# 728.5
# размах 7.399999999999977
# среднее 731.3697478991595
# медианное 731.3
# отклонение 1.5162700875683295
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 731.13931025088    731.600185547439
# коэффициент вариации  0.20731922422601917 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Давление ночь
# 734.5
# 729.4
# размах 5.100000000000023
# среднее 731.5324999999999
# медианное 731.3499999999999
# отклонение 1.0695861568827758
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 731.370637360027    731.6943626399728
# коэффициент вариации  0.1462117071876883 %
# Облачность день
# 100
# 50
# размах 50
# среднее 89.83193277310924
# медианное 90.0
# отклонение 3.918517973456575
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 89.23640953885987    90.42745600735861
# коэффициент вариации  4.362054619656992 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Облачность ночь
# 90
# 90
# размах 0
# среднее 90.0
# медианное 90.0
# отклонение 0.0
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 90.0    90.0
# коэффициент вариации  0.0 %
# Ветер день
# 360.0
# 0.0
# размах 360.0
# среднее 190.77731092436974
# медианное 180.0
# отклонение 53.90894722246831
# критичекое значение при  уровне значимости  95.0 % и  118  степени(ях) свободы 1.6578695221021444
# доверительный интервал для среднего 182.5844097248932    198.9702121238463
# коэффициент вариации  28.257525468445017 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Ветер ночь
# 360.0
# 0.0
# размах 360.0
# среднее 196.875
# медианное 202.5
# отклонение 51.343695409062626
# критичекое значение при  уровне значимости  95.0 % и  119  степени(ях) свободы 1.657759284934641
# доверительный интервал для среднего 189.10505455764647    204.64494544235353
# коэффициент вариации  26.079337350634983 %
# корреляция T/Po
# день
# значение коэффициента корреляции Пирсона  -0.5278822069265112
# t критерий наблюдаемый -6.722949263325491
# t критерий по таблице  1.6579816587044385
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# ночь
# значение коэффициента корреляции Пирсона  -0.04984068581874896
# t критерий наблюдаемый -0.5420821397152452
# t критерий по таблице  1.6578695221021444
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# x=T  y=U
# уравнение линейной регрессии
# y=-3.435938131923962x+168.1968256867803
# x=T  y=U
# уравнение линейной регрессии
# y=-3.6202151210119187x+177.23704548199927
#
# //////////////////////////////////////////////////////////////////////////////////
# номер месяца  7
#
# Температура день
# 35.4
# 21.1
# размах 14.299999999999997
# среднее 28.76747967479675
# медианное 28.7
# отклонение 2.8188053852747177
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 28.346219676781665    29.188739672811835
# коэффициент вариации  9.798583042866557 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Температура ночь
# 30.9
# 20.8
# размах 10.099999999999998
# среднее 24.884677419354837
# медианное 24.7
# отклонение 1.887734675137033
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 24.60371982298558    25.165635015724096
# коэффициент вариации  7.585931870142662 %
# Влажность день
# 98.0
# 50.0
# размах 48.0
# среднее 72.14634146341463
# медианное 72.0
# отклонение 11.032025647866735
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 70.49764619456059    73.79503673226867
# коэффициент вариации  15.291178213743617 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Влажность ночь
# 99.0
# 65.0
# размах 34.0
# среднее 89.70967741935483
# медианное 91.0
# отклонение 7.080997445267322
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 88.65578989568854    90.76356494302112
# коэффициент вариации  7.893236994005286 %
# Давление день
# 734.5
# 727.9
# размах 6.600000000000023
# среднее 730.8219512195124
# медианное 730.8
# отклонение 1.2611741883038032
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 730.633473420074    731.0104290189507
# коэффициент вариации  0.17256928123181023 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Давление ночь
# 732.5
# 728.5
# размах 4.0
# среднее 731.1580645161291
# медианное 731.2
# отклонение 0.820518159197994
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 731.0359441711347    731.2801848611235
# коэффициент вариации  0.11222172044850552 %
# Облачность день
# 100
# 40
# размах 60
# среднее 88.57723577235772
# медианное 90.0
# отклонение 6.315200093199418
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 87.63345256808846    89.52101897662699
# коэффициент вариации  7.129597168091129 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Облачность ночь
# 100
# 75
# размах 25
# среднее 89.95967741935483
# медианное 90.0
# отклонение 3.867347304485056
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 89.38408773649097    90.5352671022187
# коэффициент вариации  4.298978626231707 %
# Ветер день
# 360.0
# 0.0
# размах 360.0
# среднее 206.890243902439
# медианное 202.5
# отклонение 50.48901718148909
# критичекое значение при  уровне значимости  95.0 % и  122  степени(ях) свободы 1.6574394994001826
# доверительный интервал для среднего 199.34484776095093    214.4356400439271
# коэффициент вариации  24.40376898840027 %
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Ветер ночь
# 360.0
# 0.0
# размах 360.0
# среднее 187.0766129032258
# медианное 202.5
# отклонение 56.109059001930284
# критичекое значение при  уровне значимости  95.0 % и  123  степени(ях) свободы 1.657336397041689
# доверительный интервал для среднего 178.72572198653546    195.42750381991613
# коэффициент вариации  29.992556595492424 %
# корреляция T/Po
# день
# значение коэффициента корреляции Пирсона  -0.613765072202382
# t критерий наблюдаемый -8.551630490339504
# t критерий по таблице  1.6575443190799364
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
# ночь
# значение коэффициента корреляции Пирсона  -0.12657199645929773
# t критерий наблюдаемый -1.409368348549468
# t критерий по таблице  1.6574394994001826
# критерий наблюдаемый меньше табличного, полученное значение коэффициента корреляции не признается значимым
